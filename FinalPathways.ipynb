# %%
import cobra
from cobra import Model,Reaction,Metabolite
import escher
from escher import Builder
model = Model('model')

# %%
                                                     # Reactions
    
                                                    ### glycolysis
        
        # 1 gly ---> 2 pyru

# first reaction -----> HK                    # Gluc + ATP → G6P + ADP + H

HK = Reaction("HK")
HK.name = "Hexokinase"
HK.lower_bound = 0
HK.upper_bound = 1000

# second reaction -----> PGI                  # G6P ↔ F6P

PGI = Reaction("PGI")
PGI.name = "Glucose 6-phosphate isomerase"
PGI.lower_bound = -1000
PGI.upper_bound =  1000

# Third reaction -----> PFK                   # F6P + ATP → FDP + ADP + H+

PFK = Reaction("PFK")
PFK.name = "Phosphofructokinase"
PFK.lower_bound = 0
PFK.upper_bound = 1000

# 4th reaction -----> TPI                    # DHAP ↔ GAP

TPI = Reaction("TPI")
TPI.name = "Triose-phosphate isomerase"
TPI.lower_bound = -1000
TPI.upper_bound =  1000

# 5th reaction -----> ALD                    # FDP ↔ DHAP + GAP

ALD = Reaction("ALD")
ALD.name = "Fructose 1,6-diphosphate aldolase"
ALD.lower_bound = -1000
ALD.upper_bound =  1000

# 6th reaction -----> GAPDH                  # GAP + NAD + Pi ↔ DPG13 + NADH + H+

GAPDH = Reaction("GAPDH")
GAPDH.name = "Glyceraldehyde 3-phosphate dehydrogenase"
GAPDH.lower_bound = -1000
GAPDH.upper_bound =  1000

# 7th reaction -----> PGK                   # DPG13 + ADP ↔ PG3 + ATP

PGK = Reaction("PGK")
PGK.name = "Phosphoglycerate kinase"
PGK.lower_bound = -1000
PGK.upper_bound =  1000

# 8th reaction -----> PGLM                 # PG3 ↔ PG2

PGLM = Reaction("PGLM")
PGLM.name = "Phosphoglycerate mutase"
PGLM.lower_bound = -1000
PGLM.upper_bound =  1000

# 9th reaction -----> ENO                  # PG2 ↔ PEP + H2O

ENO= Reaction("ENO")
ENO.name = "Enolase"
ENO.lower_bound = -1000
ENO.upper_bound =  1000

# 10th reaction -----> PK                 # PEP + ADP + H+ → PYR + ATP

PK = Reaction("PK")
PK.name = "Pyruvate kinase"
PK.lower_bound = 0
PK.upper_bound = 1000

# 11th reaction -----> LDH                # PYR + NADH + H+ ↔ LAC + NAD 

LDH= Reaction("LDH")
LDH.name = "Lactate dehydrogenase"
LDH.lower_bound = -1000
LDH.upper_bound =  1000

# 12th reaction -----> AMP               # AMP →

AMP_ = Reaction("AMP_")
AMP_.name = "AMP export"
AMP_.lower_bound = 0
AMP_.upper_bound = 1000

# 13th reaction -----> APK              # 2ADP ↔ AMP + ATP

APK = Reaction("APK")
APK.name = "Adenylate kinase"
APK.lower_bound = -1000
APK.upper_bound =  1000

# 14th reaction -----> PYR             # PYR ↔ 

PYR_ = Reaction("PYR_")
PYR_.name = "Pyruvate exchange"
PYR_.lower_bound = -1000
PYR_.upper_bound = 1000

# 15th reaction -----> LAC            # LAC ↔ 

LAC_ = Reaction("LAC_")
LAC_.name = "Lactate exchange"
LAC_.lower_bound = -1000
LAC_.upper_bound = 1000

# 16th reaction -----> ATP            # ATP + H2O → ADP + Pi + H+

ATP_ = Reaction("ATP_")
ATP_.name = "ATP hydrolysis"
ATP_.lower_bound = 0
ATP_.upper_bound = 1000

# 17th reaction -----> NADH          # NADH → NAD + H+

NADH_ = Reaction("NADH_")
NADH_.name = "NADH oxidation"
NADH_.lower_bound = 0
NADH_.upper_bound = 1000

# 18th reaction -----> GLUin         #  → Gluc

GLUin = Reaction("GLUin")
GLUin.name = "Glucose import"
GLUin.lower_bound = 1
GLUin.upper_bound = 1

# 19th reaction -----> AMPin         #  → AMP

AMPin = Reaction("AMPin")
AMPin.name = "AMP import"
AMPin.lower_bound = 1
AMPin.upper_bound = 1

# 20th reaction -----> H            #  H+ ↔

H_ = Reaction("H_")
H_.name = "Proton exchange"
H_.lower_bound = -1000
H_.upper_bound = 1000

# 21th reaction -----> H2O          #  H2O ↔

H2O_ = Reaction("H2O_")
H2O_.name = "Water exchange"
H2O_.lower_bound = -1000
H2O_.upper_bound = 1000
                                                     ### Pentose pathway
    
# 22th reaction  -----> G6PDH         G6P+NADP → GL6P+NADPH + H

G6PDH = Reaction("G6PDH")
G6PDH.name = "G6P dehydrogenasee"
G6PDH.lower_bound = 0
G6PDH.upper_bound = 1000

# 23th reaction  -----> PGLase        GL6P+H2O → GO6P + H

PGLase = Reaction("PGLase")
PGLase.name = "6-Phosphogluconolactonase"
PGLase.lower_bound = 0
PGLase.upper_bound = 1000

# 24th reaction  -----> GL6PDH         GO6P+NADP → RU5P+NADPH+CO2

GL6PDH = Reaction("GL6PDH")
GL6PDH.name = "GO6P dehydrogenase"
GL6PDH.lower_bound = 0
GL6PDH.upper_bound = 1000

# 25th reaction  -----> R5PE         RU5P ↔ X5P

R5PE = Reaction("R5PE")
R5PE.name = "X5P epimerase"
R5PE.lower_bound = -1000
R5PE.upper_bound =  1000

# 26th reaction  -----> R5PI        RU5P ↔ R5P

R5PI = Reaction("R5PI")
R5PI.name = "R5P isomerase"
R5PI.lower_bound = -1000
R5PI.upper_bound =  1000

# 27th reaction  -----> TKI       X5P+R5P ↔ S7P + GAP

TKI = Reaction("TKI")
TKI.name = "Transketolase I"
TKI.lower_bound = -1000
TKI.upper_bound =  1000

# 28th reaction  -----> TKII       X5P+E4P ↔ F6P+GAP

TKII = Reaction("TKII")
TKII.name = "Transketolase II"
TKII.lower_bound = -1000
TKII.upper_bound =  1000

# 29th reaction  -----> TALA       S7P+GAP ↔ E4P+ F6P

TALA = Reaction("TALA")
TALA.name = "Transaldolase"
TALA.lower_bound = -1000
TALA.upper_bound =  1000

# 30th reaction  -----> GSSGR       GSSG+NADPH+H ↔ 2GSH + NADP

GSSGR = Reaction("GSSGR")
GSSGR.name = "Glutathione reductase"
GSSGR.lower_bound = -1000
GSSGR.upper_bound =  1000

# 31th reaction  -----> GSHR       2GSH ↔ GSSG + 2H

GSHR = Reaction("GSHR")
GSHR.name = "Glutathione oxidase"
GSHR.lower_bound = -1000
GSHR.upper_bound =  1000

# 32th reaction  -----> CO2_exch       CO2_in → CO2_out

CO2_exch = Reaction("CO2_exch")
CO2_exch.name = "freely exchanging CO2"
CO2_exch.lower_bound = -1000
CO2_exch.upper_bound = 1000

                                                      ### TCA CYCLE 

# 33th reaction  -----> Pyruvate_dehydrogenase_complex   PYR + NAD + COA ↔ Acetyl_COA + CO2 + NADH

PDC=Reaction('Pyruvate_dehydrogenase_complex')
PDC.name='Pyruvate dehydrogenase complex'
PDC.lower_bound = -1000
PDC.upper_bound =  1000

# 34th reaction  -----> Citrate synthase

CS=Reaction('CS')  
CS.name='Citrate synthase'
CS.lower_bound = -1000.0
CS.upper_bound =  1000.0 

# 35th reaction  -----> Aconitase (half-reaction A, Citrate hydro-lyase)

ACONTa=Reaction('ACONTa') 
ACONTa.name='Aconitase_1'
ACONTa.lower_bound = -1000.0
ACONTa.upper_bound =  1000.0

# 36th reaction  -----> Aconitase (half-reaction A, Citrate hydro-lyase)

ACONTb=Reaction('ACONTb') 
ACONTb.name='Aconitase_2'
ACONTb.lower_bound = -1000.0
ACONTb.upper_bound =  1000.0

# 37th reaction  -----> Isocitrate dehydrogenase (NADP)

ICDHyr=Reaction('ICDHyr') 
ICDHyr.name='Isocitrate dehydrogenase (NADP)'
ICDHyr.lower_bound = -1000.0
ICDHyr.upper_bound =  1000.0

# 38th reaction  -----> α-ketoglutarate dehydrogenase

AKGDH=Reaction('AKGDH') 
AKGDH.name='α-ketoglutarate dehydrogenase'
AKGDH.lower_bound = -1000
AKGDH.upper_bound = 1000.0

# 39th reaction  -----> Succinyl-CoA synthetase (ADP-forming)

SUCOAS=Reaction('SUCOAS') 
SUCOAS.name='Succinyl-CoA synthetase (ADP-forming)'
SUCOAS.lower_bound = -1000.0
SUCOAS.upper_bound =  1000.0

# 40th reaction  -----> Succinate dehydrogenase (irreversible)

SUCDi=Reaction('SUCDi') 
SUCDi.name='Succinate dehydrogenase (irreversible)'
SUCDi.lower_bound = -1000
SUCDi.upper_bound =  1000.0

# 41th reaction  -----> Fumarase

FUM=Reaction('FUM') 
FUM.name='Fumarase'
FUM.lower_bound = -1000.0
FUM.upper_bound =  1000.0

# 42th reaction  -----> Malate dehydrogenase

MDH=Reaction('MDH') 
MDH.name='Malate dehydrogenase'
MDH.lower_bound = -1000.0
MDH.upper_bound =  1000.0

                                                   ### Oxidative Phoso  
    
# 43th reaction  -----> NADHQ                    NADH + Q + 5H → NAD + QH2 + 4H 
        
NADHQ=Reaction('NADHQ')
NADHQ.name='NADH-coenzyme Q oxidoreductase (complex I)'
NADHQ.lower_bound = 0
NADHQ.upper_bound = 1000

# 44th reaction  -----> SUCCQ                    Succinate + Q → QH2 + Fumarate

SUCCQ=Reaction('SUCCQ')
SUCCQ.name='Succinate-Q oxidoreductase (complex II)'
SUCCQ.lower_bound = 0
SUCCQ.upper_bound = 1000

# 45th reaction  -----> QUIN                      QH2 + 2Fe3+  → Q + 2Fe2+ + 2H  

QUIN=Reaction('QUIN')
QUIN.name='Quinol--cytochrome-c reductase (complex III)'
QUIN.lower_bound = 0
QUIN.upper_bound = 1000

# 46th reaction  -----> CYTO                       8H + 4Fe2+ + O2 → 2H2O + 4Fe3+ + 4H 

CYTO=Reaction('CYTO')
CYTO.name='Cytochrome-c oxidase (complex IV)'
CYTO.lower_bound = 0
CYTO.upper_bound = 1000

# 47th reaction  -----> ATPase                     ATP + 4H + H2O ↔ ADP + 5H + P 

ATPase=Reaction('ATPase')
ATPase.name='H(+)-transporting two-sector ATPase'
ATPase.lower_bound = -1000
ATPase.upper_bound =  1000

# 48th reaction  -----> Phos                        Pi + H2O ↔ H + 2P 

Phos=Reaction('Phos')
Phos.name='Inorganic diphosphatase'
Phos.lower_bound =  0
Phos.upper_bound =  1000

# 49th reaction  -----> ATPPoly                     PPi + ATP ↔ ADP + PPPi

ATPPoly=Reaction('ATPPoly')
ATPPoly.name='ATP-polyphosphate phosphotransferase'
ATPPoly.lower_bound = -1000
ATPPoly.upper_bound =  1000

# 50th reaction
PTAr=Reaction("PTAr")
PTAr.name='Phosphotransacetylase'
PTAr.lower_bound=-1000
PTAr.upper_bound=1000

# 51th reaction
ACK=Reaction("ACK")
ACK.name='Acetate kinase'
ACK.lower_bound=-1000
ACK.upper_bound=1000

# 52th reaction
Acetate_exchange=Reaction('Acetate_exchange')
Acetate_exchange.name='Acetate exchange'
Acetate_exchange.lower_bound=0
Acetate_exchange.upper_bound=1000

# 53th reaction
α_Ketoglutarate_exchange=Reaction('α_Ketoglutarate_exchange')
α_Ketoglutarate_exchange.name='α_Ketoglutarate_exchange'
α_Ketoglutarate_exchange.lower_bound=0
α_Ketoglutarate_exchange.upper_bound=1000

# 54th reaction
Fumarate_exchange=Reaction('Fumarate_exchange')
Fumarate_exchange.name='Fumarate_exchange'
Fumarate_exchange.lower_bound=0
Fumarate_exchange.upper_bound=1000

# 55th reaction
Glucose_exchange=Reaction('Glucose_exchange')
Glucose_exchange.name='Glucose_exchange'
Glucose_exchange.lower_bound=0
Glucose_exchange.upper_bound=1000

# 56th reaction
L_Malate_exchange=Reaction('L_Malate_exchange')
L_Malate_exchange.name='L_Malate_exchange'
L_Malate_exchange.lower_bound=0
L_Malate_exchange.upper_bound=1000

# 57th reaction
O2_exchange=Reaction('O2_exchange')
O2_exchange.name='O2_exchange'
O2_exchange.lower_bound=-1000
O2_exchange.upper_bound=1000

# 58th reaction
phosphate_exchange=Reaction('phosphate_exchange')
phosphate_exchange.name='phosphate_exchange'
phosphate_exchange.lower_bound=-1000
phosphate_exchange.upper_bound=1000

# 59th reaction
Succinate_exchange=Reaction('Succinate_exchange')
Succinate_exchange.name='Succinate_exchange'
Succinate_exchange.lower_bound=0
Succinate_exchange.upper_bound=1000


                                                        ### BioMass
# BioMass reaction  -----> BioMass

BioMass=Reaction('BioMass')
BioMass.name='Biomass Objective Function with GAM'
BioMass.lower_bound = 0
BioMass.upper_bound = 1000

# %%
                                                  # Metabolites
Gluc = Metabolite(
        "Gluc",
        formula = "C6H12O6",
        name = "Glucose",
        compartment = 'c'
)
ATP = Metabolite(
        "ATP",
        formula = "C10H12N5O13P3",
        name = "Adenosine tri-phosphate",
        compartment = 'c'
)
G6P = Metabolite(
        "G6P",
        formula = "C6H13O9P",
        name = "Glucose 6-phosphate",
        compartment = 'c'
)
ADP = Metabolite(
        "ADP",
        formula = "C10H15N5O10P2",
        name = "Adenosine di-phosphate",
        compartment = 'c'
)
H = Metabolite(
        "H",
        formula = "H",
        name = "Proton",
        compartment = 'c'
)
F6P = Metabolite(
        "F6P",
        formula = "C6H13O9P",
        name = "Fructose 6-phosphate",
        compartment = 'c'
)
FDP = Metabolite(
        "FDP",
        formula = "C6H14O12P2",
        name = "Fructose 1,6-diphosphate",
        compartment = 'c'
)
DHAP = Metabolite(
        "DHAP",
        formula = "C3H7O6P",
        name = "Dihydroxyacetone phosphate",
        compartment = 'c'
)
GAP = Metabolite(
        "GAP",
        formula = "C3H7O6P",
        name = "Glyceraldehyde 3-phosphate",
        compartment = 'c'
)
NAD = Metabolite(
        "NAD",
        formula = "C21H27N7O14P2",
        name = "Nicotinamide adenine dinucleotide",
        compartment = 'c'
)

Pi = Metabolite(
        "Pi",
        formula = "PO4",
        name = "Inorganic phosphate",
        compartment = 'c'
)

DPG13 = Metabolite(
        "DPG13",
        formula = "C3H6O10P2",
        name = "1,3-Diphosphoglycerate",
        compartment = 'c'
)
NADH = Metabolite(
        "NADH",
        formula = "C21H27N7O14P2",
        name = "Nicotinamide adenine dinucleotide",
        compartment = 'c'
)
PG3 = Metabolite(
        "PG3",
        formula = "C3H7O7P",
        name = "3-Phosphoglycerate",
        compartment = 'c'
)
PG2 = Metabolite(
        "PG2",
        formula = "C3H7O7P",
        name = "2-Phosphoglyceratee",
        compartment = 'c'
)
PEP = Metabolite(
        "PEP",
        formula = "C3H5O6P",
        name = "Phosphoenolpyruvic acid",
        compartment = 'c'
)

H2O = Metabolite(
        "H2O",
        formula = "H₂O",
        name = "Water",
        compartment = 'c'
)
PYR = Metabolite(
        "PYR",
        formula = "C3H4O3",
        name = "Pyruvic acid",
        compartment = 'c'
)
LAC = Metabolite(
        "LAC",
        formula = "C3H6O3",
        name = "Lactate",
        compartment = 'c'
)
AMP = Metabolite(
        "AMP",
        formula = "C10H14N5O7P",
        name = "Adenosine monophosphate",
        compartment = 'c'
)
GL6P = Metabolite(
        "GL6P",
        formula = "C6H11O9P",
        name = "6-Phosphogluconolactone",
        compartment = 'c'
)
GO6P = Metabolite(
        "GO6P",
        formula = "C6H13O10P",
        name = "6-Phosphogluconic acid",
        compartment = 'c'
)
RU5P = Metabolite(
        "RU5P",
        formula = "C5H11O8P",
        name = "Ribulose 5-phosphate",
        compartment = 'c'
)
X5P = Metabolite(
        "X5P",
        formula = "C5H11O8P",
        name = "Xylulose 5-phosphate",
        compartment = 'c'
)
R5P = Metabolite(
        "R5P",
        formula = "C5H11O8P",
        name = "Ribose 5-phosphate",
        compartment = 'c'
)
S7P = Metabolite(
        "S7P",
        formula = "C7H15O10P",
        name = "Sedoheptulose 7-phosphate",
        compartment = 'c'
)
E4P = Metabolite(
        "E4P",
        formula = "C4H9O7P",
        name = "Erythrose 4-phosphate",
        compartment = 'c'
)
NADP = Metabolite(
        "NADP",
        formula = "C21H29N7O17P3",
        name = "Nicotinamide adenine dinucleotide phosphate",
        compartment = 'c'
)
NADPH = Metabolite(
        "NADPH",
        formula = "C21H29N7O17P3",
        name = "Nicotinamide adenine dinucleotide phosphate",
        compartment = 'c'
)
GSH = Metabolite(
        "GSH",
        formula = "C10H17N3O6S",
        name = "Glutathione",
        compartment = 'c'
)
GSSG = Metabolite(
        "GSSG",
        formula = "C20H32N6O12S2",
        name = "Glutathione disulfide",
        compartment = 'c'
)
CO2 = Metabolite(
        "CO2",
        formula = "CO2",
        name = "Carbon dioxide",
        compartment = 'c'
)
COA = Metabolite(
        "COA",
        formula = "C21H32N7O16P3S",
        name = "Coenzyme A",
        compartment = 'c'
)
Acetyl_CoA = Metabolite(
    'Acetyl_CoA',
     formula="C23H38N7O17P3S",
     name= "Acetyl CoA",
     compartment='c'
)
Oxa = Metabolite(
        "oxa",
        formula = "C4H2O5",
        name = "Oxaloacetate",
        compartment = 'c'
)
ACCOA = Metabolite(
        'ACCOA',
        name="Acetyl-CoA",
        formula="C23H34N7O17P3S",
        compartment='c'
)
CIT = Metabolite(
        'CIT',
        name="Citrate",
        formula="C6H5O7",
        compartment='c'
)
cis_acon = Metabolite(
        'acon_C_c',
        name="Cis-Aconitate",
        formula="C6H3O6",
        compartment='c'
)

ISC = Metabolite(
        'isc',
        name="Isocitrate",
        formula="C6H8O7",
        compartment='c'
)
AKG = Metabolite(
        'akg',
        name="2-Oxoglutarate",
        formula="C5H4O5",
        compartment='c'
)
SUCCOA = Metabolite(
        'succoa',
        name="Succinyl-CoA",
        formula="C25H35N7O19P3S",
        compartment='c'
)
SUCC = Metabolite(
        'succ',
        name="Succinate",
        formula="C4H4O4",
        compartment='c'
)

FAD = Metabolite(
        'fad',
        name="FAD C27H33P2N9O15",
        formula="C27H33P2N9O15",
        compartment='c'
)

FADH2 = Metabolite(
        'fadh2',
        name="FADH2 C27H35N9O15P2",
        formula="C27H35N9O15P2",
        compartment='c'
)

FUMA = Metabolite(
        'fuma',
        name="Fumarate",
        formula="C4H2O4",
        compartment='c'
)

MAL = Metabolite(
        'mal',
        name="L-Malate",
        formula="C4H4O5",
        compartment='c'
)
Q = Metabolite(
    'Q',
    formula='C9H10O4(C5H8)n',
    name='a ubiquinone',
    compartment='c'
)
QH2 = Metabolite(
    'QH2',
    formula='C9H12O4(C5H8)n',
    name='a ubiquinol',
    compartment='c'
)

Fe3 = Metabolite(
    'Fe3',
    formula='Fe',
    name='Fe(III)-[cytochrome c]',
    compartment='c'
)
Fe2 = Metabolite(
    'Fe2',
    formula='Fe',
    name='Fe(II)-[cytochrome c]',
    compartment='c'
)
O2 = Metabolite(
    'O2',
    formula='O2',
    name='O2',
    compartment='c'
)

diphosphate = Metabolite(
    'PPi',
   formula='',
    name='diphosphate',
    compartment='c'
)
actp=Metabolite(
    'Acetyl_phosphate',
    name= "Acetyl phosphate",
    formula="C2H3O5P",
    compartment='c'
)
ac=Metabolite(
    'Acetate',
    name= "Acetate",
    formula="C2H3O2",
    compartment='c'
)

# %%
                                               # add_metabolites

HK.add_metabolites({Gluc: -1, ATP: -1, G6P: 1, ADP: 1, H: 1})
PGI.add_metabolites({G6P: -1, F6P: 1}) 
PFK.add_metabolites({F6P: -1, ATP: -1, FDP: 1, ADP: 1, H: 1})
TPI.add_metabolites({DHAP: -1, GAP: 1})
ALD.add_metabolites({FDP: -1, DHAP: 1, GAP: 1})
GAPDH.add_metabolites({GAP: -1, NAD: -1, Pi: -1, DPG13: 1, NADH: 1, H: 1})
PGK.add_metabolites({DPG13: -1,ADP: -1,PG3: 1,ATP: 1})
PGLM.add_metabolites({PG3: -1,PG2: 1})
ENO.add_metabolites({PG2: -1,PEP: 1,H2O: 1})
PK.add_metabolites({PEP: -1,ADP: -1,H: -1,PYR: 1 , ATP: 1})
LDH.add_metabolites({PYR: -1,NADH: -1,H: -1,LAC: 1,NAD: 1})
AMP_.add_metabolites({AMP: -1})
APK.add_metabolites({ADP: -2,AMP: 1,ATP: 1})
PYR_.add_metabolites({PYR: -1})
LAC_.add_metabolites({LAC: -1})
ATP_.add_metabolites({ATP: -1,H2O: -1,ADP: 1,Pi: 1,H: 1})
NADH_.add_metabolites({NADH: -1,NAD: 1,H: 1})
GLUin.add_metabolites({Gluc: 1})
AMPin.add_metabolites({AMP: 1})
H_.add_metabolites({H: -1})
H2O_.add_metabolites({H2O : -1})

G6PDH.add_metabolites({G6P: -1, NADP: -1, GL6P: 1, NADPH: 1, H:1}) 
PGLase.add_metabolites({GL6P: -1, H2O: -1,GO6P: 1, H:1}) 
GL6PDH.add_metabolites({ GO6P: -1, NADP: -1, RU5P: 1, NADPH:1, CO2:1}) 
R5PE.add_metabolites({ RU5P: -1, X5P: 1}) 
R5PI.add_metabolites({ RU5P: -1, R5P: 1})
TKI.add_metabolites({ X5P: -1, R5P: -1, S7P: 1, GAP: 1})
TKII.add_metabolites({ X5P: -1, E4P: -1, F6P: 1, GAP: 1})
TALA.add_metabolites({ S7P: -1, GAP: -1, E4P: 1, F6P: 1})
GSSGR.add_metabolites({ GSSG: -1, NADPH: -1, H: -1, GSH: 2, NADP: 1})
GSHR.add_metabolites({ GSH: -2, GSSG: 1, H: 2})
CO2_exch.add_metabolites({ CO2: -1})

PDC.add_metabolites({PYR:-1,NAD:-1,COA:-1,Acetyl_CoA:1,CO2:1,NADH:1})
CS.add_metabolites({ACCOA:-1,H2O:-1,Oxa:-1,CIT:1,COA:1})
ACONTa.add_metabolites({CIT:-1,cis_acon:1,H2O:1})
ACONTb.add_metabolites({cis_acon:-1,H2O:-1,ISC:1})
ICDHyr.add_metabolites({ISC:-1,NAD:-1,AKG:1,CO2:1,NADH:1,H:1})
AKGDH.add_metabolites({AKG:-1,COA:-1,NAD:-1,SUCCOA:1,CO2:1,NADH:1,H:1})
SUCOAS.add_metabolites({SUCC:1,ATP:1,COA:1,ADP:-1,Pi:-1,SUCCOA:-1})
SUCDi.add_metabolites({SUCC:-1,FAD:-1,Pi:-1,FUMA:1,FADH2:1})
FUM.add_metabolites({FUMA:-1,H2O:-1,MAL:1})
MDH.add_metabolites({MAL:-1,NAD:-1,Oxa:1,NADH:1,H:1})

NADHQ.add_metabolites({NADH:-1,Q:-1,H:-5,NAD:1,QH2:1,H:4})
SUCCQ.add_metabolites({SUCC:-1,Q:-1,FUMA:1,QH2:1})
QUIN.add_metabolites({QH2:-1,Fe3:-2,Q:1,Fe2:2,H:2})
CYTO.add_metabolites({Fe2:-4,H:-8,O2:-1,Fe3:4,H:4,H2O:2})
ATPase.add_metabolites({ATP:-1,H:-4,H2O:-1,ADP:1,H:5,Pi:1})            
Phos.add_metabolites({diphosphate:-1,H2O:-1,H:1,Pi:2})
ATPPoly.add_metabolites({Pi:-1,ATP:-1,Pi:2,ADP:1})
#######
PTAr.add_metabolites({Acetyl_CoA:-1,Pi:-1,COA:-1,actp:1})
ACK.add_metabolites({actp:-1,ADP:-1,ac:1,ATP:1})
Acetate_exchange.add_metabolites({ac:-1})
α_Ketoglutarate_exchange.add_metabolites({AKG:-1})
Fumarate_exchange.add_metabolites({FUMA:-1})
Glucose_exchange.add_metabolites({Gluc:-1})
L_Malate_exchange.add_metabolites({MAL:-1})
O2_exchange.add_metabolites({O2:-1})
phosphate_exchange.add_metabolites({Pi:-1})
Succinate_exchange.add_metabolites({SUCC:-1})
######

BioMass.add_metabolites({PG3:-1.496,ATP:-59.81,E4P:-0.361,Acetyl_CoA:-3.7478,F6P:-0.0709,GAP:-0.129,G6P:-0.205,H2O:-59.81,Oxa :-1.7867,PYR:-2.8328,PEP:-0.5191,R5P:-0.8977,NAD:-3.547,NADPH:-13.0279,COA:3.7478,ADP:59.81,Pi:59.81,AKG:4.1182,NADP:13.0279,NADH:3.547,H:59.81})

# %%
                                               # add_reactions
model.add_reactions({HK,PGI,PFK,TPI,ALD,GAPDH,PGK,PGLM,ENO,PK,LDH,AMP_,APK,PYR_,LAC_,ATP_,NADH_,GLUin,AMPin,H_, H2O_,G6PDH,PGLase,GL6PDH,R5PE,R5PI,TKI,TKII,TALA,GSSGR,GSHR,CO2_exch,PDC,CS,ACONTa,ACONTb,ICDHyr,AKGDH,SUCOAS,SUCDi,FUM,MDH,NADHQ,SUCCQ,QUIN,CYTO,ATPase,Phos,ATPPoly,PTAr,ACK,Acetate_exchange,α_Ketoglutarate_exchange,Fumarate_exchange,Glucose_exchange,L_Malate_exchange,O2_exchange,phosphate_exchange,Succinate_exchange,BioMass})

# %%
model.objective = "BioMass"

# %%
model.optimize()
# Out:
# <Solution 0.428 at 0x27d6e06b3a0>

# %%
model.optimize().fluxes
# Out:
# FUM                                0.764625
# PFK                                0.574314
# TALA                              -0.076561
# MDH                                0.764625
# α_Ketoglutarate_exchange           0.000000
# TKII                              -0.231052
# Acetate_exchange                   0.000000
# SUCDi                              0.000000
# TKI                               -0.076561
# ACK                                0.000000
# SUCOAS                             1.762400
# R5PI                               0.307613
# PTAr                               0.000000
# AKGDH                              1.762400
# R5PE                              -0.307613
# ATPPoly                           -6.395233
# ICDHyr                             0.000000
# GL6PDH                             0.000000
# Phos                               0.000000
# NADH_                              2.103889
# PGLase                             0.000000
# ...

# %%
cobra.io.save_json_model(model,"task3.json")

# %%
builder = Builder(model_json = "task3.json")
builder.reaction_data=model.optimize().fluxes

# %%
builder
# Out:
# Builder(reaction_data={'FUM': 0.7646253263148898, 'PFK': 0.5743142037916743, 'TALA': -0.0765609620404848, 'MDH…
